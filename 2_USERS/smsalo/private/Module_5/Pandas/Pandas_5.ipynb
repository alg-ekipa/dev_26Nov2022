# %%
import pandas as pd

# %%
listings_df= pd.read_csv('airbnb_new_york_city_listings.csv')
listings_df
# Out:
#              id                                               name   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...      4869
# 2          5121                                    BlissArtsSpace!      7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden      7378
# 4          5178                   Large Furnished Room Near B'way　      8967
# ...         ...                                                ...       ...
# 36719  51447515         Gorgeous 2 Bedroom - in Prime Midtown East  51589519
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...   2971741
# 36721  51450816                                    The Hunter IIII  61391963
# 36722  51451029                        Rockaway Beach Surf Getaway  10123226
# 36723  51451368                       Nyc apt in the middle in nyc  17770287
#
# ...

# %%
listings_df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
#listings_df['last_review'] =  listings_df['last_review'].astype('datetime64')
listings_df['last_review']=pd.to_datetime(listings_df['last_review'])
listings_df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# dtype: object

# %%
listings_df['price']=listings_df['price'].astype('float')
listings_df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                    float64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# dtype: object

# %%
listings_df['last_review_year']=listings_df['last_review'].dt.year
#kreiramo novi stupac, uzimamo godinu iz stupca last review

listings_df
# Out:
#              id                                               name   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...      4869
# 2          5121                                    BlissArtsSpace!      7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden      7378
# 4          5178                   Large Furnished Room Near B'way　      8967
# ...         ...                                                ...       ...
# 36719  51447515         Gorgeous 2 Bedroom - in Prime Midtown East  51589519
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...   2971741
# 36721  51450816                                    The Hunter IIII  61391963
# 36722  51451029                        Rockaway Beach Surf Getaway  10123226
# 36723  51451368                       Nyc apt in the middle in nyc  17770287
#
# ...

# %%
listings_df.isnull().sum()
# Out:
# id                                   0
# name                                13
# host_id                              0
# host_name                           23
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9415
# reviews_per_month                 9415
# calculated_host_listings_count       0
# availability_365                     0
# last_review_year                  9415
# dtype: int64

# %%
listings_df['name'].fillna('No name listing', inplace=True)   #.fillna naredba za dodavanje vrijednosti praznim poljima

# %%
listings_df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                           23
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9415
# reviews_per_month                 9415
# calculated_host_listings_count       0
# availability_365                     0
# last_review_year                  9415
# dtype: int64

# %%
listings_df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                    float64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# last_review_year                         float64
# dtype: object

# %%
listings_df['host_name'].fillna('J.Doe', inplace=True)
listings_df['last_review'].fillna('01-01-1970', inplace=True)
listings_df['reviews_per_month'].fillna(0.0, inplace=True)
listings_df['last_review_year'].fillna(0.0, inplace=True)

# %%
listings_df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# last_review_year                  0
# dtype: int64

# %%
listings_df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                    float64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# last_review_year                         float64
# dtype: object

# %%
listings_df['last_review_year']=listings_df['last_review_year'].astype('int64')

# %%
listings_df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                    float64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# last_review_year                           int64
# dtype: object

# %%
listings_df['name']=listings_df['name'].str.strip()   #čišćenje zankova prije i poslije (npr \n)
listings_df['host_name']=listings_df['host_name'].str.strip()
listings_df['neighbourhood_group']=listings_df['neighbourhood_group'].str.strip()
listings_df['neighbourhood']=listings_df['neighbourhood'].str.strip()
listings_df['room_type']=listings_df['room_type'].str.strip()

# %%
listings_df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                    float64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# last_review_year                           int64
# dtype: object

# %%
listings_df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# last_review_year                  0
# dtype: int64

# %% [markdown]
# # operacije nad stupcima

# %%
listings_df['min_revenue']=listings_df['price']*listings_df['minimum_nights']
listings_df
# Out:
#              id                                               name   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...      4869
# 2          5121                                    BlissArtsSpace!      7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden      7378
# 4          5178                    Large Furnished Room Near B'way      8967
# ...         ...                                                ...       ...
# 36719  51447515         Gorgeous 2 Bedroom - in Prime Midtown East  51589519
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...   2971741
# 36721  51450816                                    The Hunter IIII  61391963
# 36722  51451029                        Rockaway Beach Surf Getaway  10123226
# 36723  51451368                       Nyc apt in the middle in nyc  17770287
#
# ...

# %% [markdown]
# # FILTRIRANJE

# %% [markdown]
# Ima li  u stupcu neighbourhood_group string 'Manhattan'?

# %%
listings_df['neighbourhood_group'].str.contains('Manhattan').any()  #barem jedan
# Out:
# True

# %%
listings_df['neighbourhood_group'].str.contains('Manhattan').all()   #da li je u svima?
# Out:
# False

# %%
listings_df['neighbourhood_group'].str.contains('Manhattan')
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 36719     True
# 36720     True
# 36721     True
# 36722    False
# 36723     True
# Name: neighbourhood_group, Length: 36724, dtype: bool

# %% [markdown]
# ## filtriranje s uvjetom

# %%
listings_df.loc[listings_df['neighbourhood_group'].str.contains('Manhattan')==True]
# Out:
#              id                                               name   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 4          5178                    Large Furnished Room Near B'way      8967
# 5          5203                 Cozy Clean Guest Room - Family Apt      7490
# 8          6872  Uptown Sanctuary w/ Private Bath (Month to Month)     16104
# 9          6990                            UES Beautiful Blue Room     16800
# ...         ...                                                ...       ...
# 36718  51447187                                   The Hunter IIIII  61391963
# 36719  51447515         Gorgeous 2 Bedroom - in Prime Midtown East  51589519
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...   2971741
# 36721  51450816                                    The Hunter IIII  61391963
# 36723  51451368                       Nyc apt in the middle in nyc  17770287
#
# ...

# %% [markdown]
# #### ZADATAK
# Statistička analiza cijena kod listinga:
#  + minimalna i maksimalna cijena
#  + raspon max i min cijene
#  + prosječna cijena
#  + medijan cijena
#  + standardna devijacija cijena
#  + ukupan broj vrijednosti cijena

# %%
listings_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.672400e+04  3.672400e+04  36724.000000  36724.000000  36724.000000
# mean   2.732247e+07  1.054899e+08     40.729355    -73.949582    160.109057
# std    1.636301e+07  1.220695e+08      0.055562      0.049611    293.888431
# min    2.595000e+03  2.420000e+03     40.508630    -74.241350      0.000000
# 25%    1.235735e+07  1.042882e+07     40.689530    -73.983170     67.000000
# 50%    2.795480e+07  4.555160e+07     40.725530    -73.954990    108.000000
# 75%    4.294918e+07  1.749868e+08     40.762752    -73.931330    175.000000
# max    5.145137e+07  4.162927e+08     40.911390    -73.705220  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    36724.000000       36724.000000       36724.000000
# mean        22.482083          22.854836           1.022812
# std         28.361534          49.188479           3.374019
# ...

# %% [markdown]
# ## sortiranje

# %%
listings_df[['room_type', 'last_review_year', 'price']].groupby(['room_type', 'last_review_year'], as_index=False).mean()
# Out:
#           room_type  last_review_year       price
# 0   Entire home/apt                 0  262.485149
# 1   Entire home/apt              2010  228.000000
# 2   Entire home/apt              2011  191.800000
# 3   Entire home/apt              2012  156.000000
# 4   Entire home/apt              2013  170.666667
# 5   Entire home/apt              2014  184.879032
# 6   Entire home/apt              2015  228.021739
# 7   Entire home/apt              2016  187.533696
# 8   Entire home/apt              2017  205.882831
# 9   Entire home/apt              2018  178.282708
# 10  Entire home/apt              2019  197.652335
# 11  Entire home/apt              2020  194.514196
# 12  Entire home/apt              2021  201.914445
# 13       Hotel room                 0  407.655738
# 14       Hotel room              2016  349.000000
# 15       Hotel room              2017  241.000000
# 16       Hotel room              2018  128.333333
# 17       Hotel room              2019  291.718750
# ...

# %%
listings_df[['room_type', 'last_review_year', 'price']].groupby(['room_type', 'last_review_year'], as_index=True).mean()
# Out:
#                                        price
# room_type       last_review_year
# Entire home/apt 0                 262.485149
#                 2010              228.000000
#                 2011              191.800000
#                 2012              156.000000
#                 2013              170.666667
#                 2014              184.879032
#                 2015              228.021739
#                 2016              187.533696
#                 2017              205.882831
#                 2018              178.282708
#                 2019              197.652335
#                 2020              194.514196
#                 2021              201.914445
# Hotel room      0                 407.655738
#                 2016              349.000000
#                 2017              241.000000
#                 2018              128.333333
#                 2019              291.718750
#                 2020              339.038462
# ...

# %% [markdown]
# ## ZADATAK
# Nad listings i ocjenama isprobati razne kolone i njihove mogućnosti sortiranja i grupiranja!
